# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import os
from collections import deque
import numpy as np
from moviepy.editor import VideoFileClip
from os.path import join, basename

import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pickle
import pdb

import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt

import os.path
import logging

from utils import show_two_images

import camera

# %%
importlib.reload(camera)

image = mpimg.imread("test_images/straight_lines2.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# calibrate camera
ret, mtx, dist, rvecs, tvecs = camera.calibrate_camera()

calibrated_image = camera.undistort(image, mtx, dist, verbose=True)

# warp

warp = camera.warp_to_birdeye(calibrated_image)


print("abc")
pdb.set_trace()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a2b96856f6f2> in <module>
#       9 # warp
#      10
# ---> 11 warp = warp_to_birdeye(calibrated_image)
#      12
#      13
#
# NameError: name 'warp_to_birdeye' is not defined
